# %% [markdown]
# social data about different parts of new yok city
# create index to select out borough and the related data

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://data.cityofnewyork.us/api/views/8ek7-jxw6/rows.csv?accessType=DOWNLOAD'

city_data = pd.read_csv(url)

# %%
city_data.columns
# Out:
# Index(['Domain', 'Indicator', 'Dimension Category', 'Dimension', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        'Defintion', 'Source', 'Notes'],
#       dtype='object')

# %% [markdown]
# Replace the * character with NaN

# %%
city_data.replace('*', np.nan, inplace=True)

# %%
city_data.head()
# Out:
#       Domain                         Indicator Dimension Category  Dimension  \
# 0  Education  Enrolled Full Day Pre-K Students           Citywide   Citywide
# 1  Education  Enrolled Full Day Pre-K Students            Borough      Bronx
# 2  Education  Enrolled Full Day Pre-K Students            Borough   Brooklyn
# 3  Education  Enrolled Full Day Pre-K Students            Borough  Manhattan
# 4  Education  Enrolled Full Day Pre-K Students            Borough     Queens
#
#   2000 2001 2002 2003 2004 2005  ...  2011 2012 2013    2014    2015    2016  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  19,287  52,741  68,647
# 1  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN   22.0%   22.7%   21.3%
# 2  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN   39.7%   32.2%   31.7%
# 3  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN   15.3%   13.8%   12.2%
# 4  NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN   18.9%   25.6%   29.0%
#
# ...

# %% [markdown]
# set the Dimension category Domain and Dimension as the index

# %%
org_city_data = city_data.set_index(['Dimension Category', 'Domain', 'Dimension'])
org_city_data.head()

# %% [markdown]
# create new dataframe with only borough information

# %%
borough_data = org_city_data.loc['Borough']
borough_data.head()
# Out:
#                                                 Indicator 2000 2001 2002 2003  \
# Domain    Dimension
# Education Bronx          Enrolled Full Day Pre-K Students  NaN  NaN  NaN  NaN
#           Brooklyn       Enrolled Full Day Pre-K Students  NaN  NaN  NaN  NaN
#           Manhattan      Enrolled Full Day Pre-K Students  NaN  NaN  NaN  NaN
#           Queens         Enrolled Full Day Pre-K Students  NaN  NaN  NaN  NaN
#           Staten Island  Enrolled Full Day Pre-K Students  NaN  NaN  NaN  NaN
#
#                         2004 2005 2006 2007 2008  ...  2011 2012 2013   2014  \
# Domain    Dimension                               ...
# Education Bronx          NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  22.0%
#           Brooklyn       NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  39.7%
#           Manhattan      NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  15.3%
#           Queens         NaN  NaN  NaN  NaN  NaN  ...   NaN  NaN  NaN  18.9%
# ...

# %% [markdown]
# created dataframe with borough education data only

# %%
borough_ed_data = borough_data.xs('Education', level='Domain')
borough_ed_data.head()
# Out:
#                                       Indicator 2000 2001 2002 2003 2004 2005  \
# Dimension
# Bronx          Enrolled Full Day Pre-K Students  NaN  NaN  NaN  NaN  NaN  NaN
# Brooklyn       Enrolled Full Day Pre-K Students  NaN  NaN  NaN  NaN  NaN  NaN
# Manhattan      Enrolled Full Day Pre-K Students  NaN  NaN  NaN  NaN  NaN  NaN
# Queens         Enrolled Full Day Pre-K Students  NaN  NaN  NaN  NaN  NaN  NaN
# Staten Island  Enrolled Full Day Pre-K Students  NaN  NaN  NaN  NaN  NaN  NaN
#
#               2006 2007 2008  ...  2011 2012 2013   2014   2015   2016   2017  \
# Dimension                     ...
# Bronx          NaN  NaN  NaN  ...   NaN  NaN  NaN  22.0%  22.7%  21.3%  20.5%
# Brooklyn       NaN  NaN  NaN  ...   NaN  NaN  NaN  39.7%  32.2%  31.7%  32.3%
# Manhattan      NaN  NaN  NaN  ...   NaN  NaN  NaN  15.3%  13.8%  12.2%  11.8%
# Queens         NaN  NaN  NaN  ...   NaN  NaN  NaN  18.9%  25.6%  29.0%  29.6%
# ...

# %% [markdown]
# drop columns where all values are NaN
# sort borough by four year high school gradutation percentage in 2015
#
# Staten Island had the highest four year high school graduation percentagein 2015

# %%
borough_ed_data.loc[borough_ed_data['Indicator'] == 'Four-Year High School Graduation Rate'].dropna(axis=1, how='all').sort_values('2015', ascending=False)
# Out:
#                                            Indicator   2011   2012   2013  \
# Dimension
# Staten Island  Four-Year High School Graduation Rate  74.2%  74.6%  75.2%
# Queens         Four-Year High School Graduation Rate  70.0%  67.6%  68.9%
# Manhattan      Four-Year High School Graduation Rate  67.3%  66.6%  67.5%
# Brooklyn       Four-Year High School Graduation Rate  64.2%  64.9%  66.2%
# Bronx          Four-Year High School Graduation Rate  57.5%  55.4%  57.5%
#
#                 2014   2015   2016  \
# Dimension
# Staten Island  79.1%  77.4%  79.3%
# Queens         70.8%  73.3%  75.5%
# Manhattan      70.6%  72.5%  74.6%
# Brooklyn       68.6%  70.8%  72.2%
# Bronx          59.1%  61.8%  64.8%
#
#                                                        Defintion  \
# Dimension
# Staten Island  The percentage of students who graduated with ...
# Queens         The percentage of students who graduated with ...
# Manhattan      The percentage of students who graduated with ...
# ...

# %% [markdown]
# create a dataframe of crime by borough

# %%
borough_crime_data = borough_data.xs('Personal & Community Safety', level='Domain')
borough_crime_data.head()
# Out:
#                                                  Indicator 2000 2001 2002  \
# Dimension
# Bronx      Admissions to Department of Correction per 1000  NaN  NaN  NaN
# Brooklyn   Admissions to Department of Correction per 1000  NaN  NaN  NaN
# Manhattan  Admissions to Department of Correction per 1000  NaN  NaN  NaN
# Bronx                               Violent Crime per 1000  NaN  NaN  NaN
# Brooklyn                            Violent Crime per 1000  NaN  NaN  NaN
#
#           2003 2004 2005 2006  2007  2008  ...   2011  2012  2013  2014  2015  \
# Dimension                                  ...
# Bronx      NaN  NaN  NaN  NaN  14.8  13.8  ...   10.1   9.2  10.2   9.1   7.9
# Brooklyn   NaN  NaN  NaN  NaN  10.3   9.2  ...    7.4   7.4   6.6   5.8   5.1
# Manhattan  NaN  NaN  NaN  NaN  18.0  16.7  ...   16.3  15.1  13.5  15.1  11.5
# Bronx      NaN  NaN  7.4  7.1   6.8   6.7  ...    6.8   7.1   7.2   6.9   7.2
# ...

# %% [markdown]
# select the rows for violent crime per 1000 and drop columns that are all NaN
# then sort from lowest to highest in 2015
#
# as we can see the order of the boroughs is the same as the order of the boroughs who had the highest graduation rate
# Staten Island has the lowest occurance of violent crime in 2015

# %%
borough_crime_data.loc[borough_crime_data['Indicator'] == 'Violent Crime per 1000'].dropna(axis=1, how='all').sort_values('2015')
# Out:
#                             Indicator 2005 2006 2007 2008 2009 2010 2011 2012  \
# Dimension
# Staten Island  Violent Crime per 1000  2.2  2.0  2.0  2.0  1.9  2.1  2.2  2.5
# Queens         Violent Crime per 1000  3.8  3.7  3.5  3.5  3.2  3.4  3.6  3.7
# Manhattan      Violent Crime per 1000  6.1  5.5  5.2  4.8  4.4  4.6  4.5  4.5
# Brooklyn       Violent Crime per 1000  6.4  5.9  5.6  5.4  4.9  5.2  5.6  5.7
# Bronx          Violent Crime per 1000  7.4  7.1  6.8  6.7  6.3  6.8  6.8  7.1
#
#               2013 2014 2015 2016  \
# Dimension
# Staten Island  2.6  2.4  2.5  2.4
# Queens         3.6  3.3  3.2  3.1
# Manhattan      4.3  4.0  4.3  4.3
# Brooklyn       5.5  5.0  4.8  4.5
# Bronx          7.2  6.9  7.2  7.4
#
#                                                        Defintion  \
# Dimension
# Staten Island  Crime categories are split into two major subc...
# Queens         Crime categories are split into two major subc...
# ...
